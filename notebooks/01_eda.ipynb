# %% [markdown]
# # Framingham EDA
# Distributions, correlations, missing-value heatmap, imputation comparison.

# %%
import pandas as pd
from cardio_risk_rf.data.framingham import load_framingham, FEATURES, TARGET
df = load_framingham('../data/raw/framingham.csv')
df.describe()
